# %%
# import necessary libaries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# read csvfile
df= pd.read_csv("travel_data_cleaned.csv")

# Want to see if the dataframe was properly imported and see what kind of data is stored in each column.
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Zone                              325 non-null    object
#  1   State                             325 non-null    object
#  2   City                              325 non-null    object
#  3   Name                              325 non-null    object
#  4   Type                              325 non-null    object
#  5   Establishment Year                325 non-null    object
#  6   time needed to visit in hrs       325 non-null    float64
#  7   Google review rating              325 non-null    float64
#  8   Entrance Fee in INR               325 non-null    int64
#  9   Airport with 50km Radius          325 non-null    object
#  10  Weekly Off                        324 non-null    object
# ...

# %%
df_sign=df.groupby("Significance").sum()
df_sign
# Out:
# /var/folders/mq/ylj5z08x5mx59bw0_nz_pfhm0000gn/T/ipykernel_13296/1573184474.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sign=df.groupby("Significance").sum()
#                     time needed to visit in hrs  Google review rating  \
# Significance
# Adventure                                  13.0                  22.7
# Agricultural                                1.5                   4.6
# Archaeological                              2.0                   4.6
# Architectural                               2.5                  18.2
# Artistic                                    5.0                   9.0
# Botanical                                   5.0                  13.2
# Cultural                                   21.5                  58.7
# ...

# %%
df
# Out:
#          Zone           State         City                          Name  \
# 0    Northern           Delhi        Delhi                    India Gate
# 1    Northern           Delhi        Delhi                Humayun's Tomb
# 2    Northern           Delhi        Delhi             Akshardham Temple
# 3    Northern           Delhi        Delhi          Waste to Wonder Park
# 4    Northern           Delhi        Delhi                 Jantar Mantar
# ..        ...             ...          ...                           ...
# 320   Western         Gujarat  Gandhinagar                    Akshardham
# 321   Central   Uttar Pradesh         Agra                     Agra Fort
# 322   Central  Madhya Pradesh       Bhopal  Madhya Pradesh Tribal Museum
# 323  Northern       Rajasthan       Jaipur                   City Palace
# 324  Northern       Rajasthan       Jaipur            Albert Hall Museum
#
#              Type Establishment Year  time needed to visit in hrs  \
# ...

# %%
df_state=df.groupby("State").sum()
df_state
# Out:
# /var/folders/mq/ylj5z08x5mx59bw0_nz_pfhm0000gn/T/ipykernel_13296/3203698936.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_state=df.groupby("State").sum()
#                              time needed to visit in hrs  \
# State
# Andaman and Nicobar Islands                          5.0
# Andhra Pradesh                                      24.0
# Arunachal Pradesh                                    2.0
# Assam                                               15.0
# Bihar                                                6.0
# Chhattisgarh                                         1.5
# Daman and Diu                                        2.5
# Delhi                                               39.5
# Goa                                                 25.0
# ...

# %%
# reading cleaned csv file with no index reference into new dataframe.
df.to_csv("travel_cleaned.csv",index=False)
df1=pd.read_csv("travel_cleaned.csv")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Zone                              325 non-null    object
#  1   State                             325 non-null    object
#  2   City                              325 non-null    object
#  3   Name                              325 non-null    object
#  4   Type                              325 non-null    object
#  5   Establishment Year                325 non-null    object
#  6   time needed to visit in hrs       325 non-null    float64
#  7   Google review rating              325 non-null    float64
#  8   Entrance Fee in INR               325 non-null    int64
#  9   Airport with 50km Radius          325 non-null    object
#  10  Weekly Off                        324 non-null    object
# ...

# %%
# creating new dataframe with establishment year and number of google review in lakhs to know analytic for people
df_reviews= df1[["Establishment Year","Number of google review in lakhs"]]
df2=df_reviews.groupby("Establishment Year")["Number of google review in lakhs"].sum()
df2.to_csv("year_to_reviews.csv")
df_year_review =pd.read_csv("year_to_reviews.csv")

# %%
df_year_review.info()
df_year_review
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 2 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Establishment Year                162 non-null    object
#  1   Number of google review in lakhs  162 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.7+ KB
#     Establishment Year  Number of google review in lakhs
# 0                 -260                             0.200
# 1                 -300                             0.010
# 2                -3500                             1.200
# 3                 -400                             0.590
# 4                 -500                             0.065
# ..                 ...                               ...
# 157                751                             0.090
# 158        7th century                             0.250
# ...
